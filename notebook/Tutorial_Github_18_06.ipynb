# %% [markdown]
# <a href="https://colab.research.google.com/github/dramirezbe/Tutorial-GIT-17-06/blob/main/notebook/Tutorial_Github_18_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial Github

# %%
import os
